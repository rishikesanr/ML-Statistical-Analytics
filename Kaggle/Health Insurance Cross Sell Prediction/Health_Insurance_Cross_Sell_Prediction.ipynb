# %% [markdown]
# # Kaggle - Health Insurance Cross Sell Prediction
# ### Rishikesan Ravichandran

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
sample_submission = pd.read_csv('./kaggle/sample_submission.csv')
sample_submission
# Out:
#                id  Response
# 0        11504798       0.5
# 1        11504799       0.5
# 2        11504800       0.5
# 3        11504801       0.5
# 4        11504802       0.5
# ...           ...       ...
# 7669861  19174659       0.5
# 7669862  19174660       0.5
# 7669863  19174661       0.5
# 7669864  19174662       0.5
# 7669865  19174663       0.5
#
# [7669866 rows x 2 columns]

# %%
#Train data 
df = pd.read_csv('./kaggle/train.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0    Male   21                1         35.0                   0
# 1   1    Male   43                1         28.0                   0
# 2   2  Female   25                1         14.0                   1
# 3   3  Female   35                1          1.0                   0
# 4   4  Female   36                1         15.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    1-2 Year            Yes         65101.0                 124.0      187
# 1   > 2 Years            Yes         58911.0                  26.0      288
# 2    < 1 Year             No         38043.0                 152.0      254
# 3    1-2 Year            Yes          2630.0                 156.0       76
# 4    1-2 Year             No         31951.0                 152.0      294
#
#    Response
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11504798 entries, 0 to 11504797
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   Gender                object
#  2   Age                   int64
#  3   Driving_License       int64
#  4   Region_Code           float64
#  5   Previously_Insured    int64
#  6   Vehicle_Age           object
#  7   Vehicle_Damage        object
#  8   Annual_Premium        float64
#  9   Policy_Sales_Channel  float64
#  10  Vintage               int64
#  11  Response              int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 1.0+ GB

# %%
df.shape
# Out:
# (11504798, 12)

# %%
# Distributions of categorical colummns 
cat_cols = ['Gender', 'Driving_License','Previously_Insured','Vehicle_Age','Vehicle_Damage']

for col in cat_cols:
    df[col].value_counts().plot(kind='bar',title=f"Distribution of {col}")
    plt.show()

# %%
# Distributions of numeric colummns 
num_cols = ['Age', 'Region_Code','Annual_Premium','Policy_Sales_Channel','Vintage']

for col in num_cols:
    df[col].plot(kind='hist',bins=10,title=f"Distribution of {col}")
    plt.show()

# %%
# Distribution of Response Variable 

df['Response'].value_counts().plot(kind='bar',title='Distribution of Response')

#There is a class imbalance
# Out:
# <Axes: title={'center': 'Distribution of Response'}>
